# %% [markdown]
# <a href="https://colab.research.google.com/github/ideepankarsharma2003/lora-sdxl/blob/master/listen2it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ideepankarsharma2003/lora-sdxl.git
# Out:
# Cloning into 'lora-sdxl'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 14 (delta 1), reused 10 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 95.43 KiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
import os; os.chdir("lora-sdxl/")
# %pwd
# Out:
# '/content/lora-sdxl'

# %%
# %ls
# Out:
# inference.py     main.py         README.md         setup.sh*  uv.lock
# listen2it.ipynb  pyproject.toml  requirements.txt  train.py

# %%
# !./setup.sh
# Out:
# Installing dependencies...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 14.3 MB/s eta 0:00:00
# ...
# Installation complete!

# %%
# !python train.py --max_train_steps=1500
# Out:
# 2025-11-25 04:02:01.062869: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764043321.099398     735 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764043321.110152     735 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764043321.135762     735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
